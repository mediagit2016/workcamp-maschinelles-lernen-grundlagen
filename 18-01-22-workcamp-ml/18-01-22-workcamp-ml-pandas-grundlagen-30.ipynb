# %% [markdown]
# <h1>Workcamp Maschinelles Lernen</h1>
# <h2>Grundlagen - Arbeiten mit Panda Dataframes</h2>
# <h3>EInlesen von Dateien in Dataframes</h3>

# %% [markdown]
# Lassen Sie uns jetzt unsere Kenntnisse erweitern. Wir wollen Files in Dataframes einlesen.
# Einlesen von csv-Dateien
# Daten sind die sunset observationen von SILSO
# Die Daten gehen bis in das 18. Jahrhundert zurück, mit über 70.000 Zeilen
# http://www.sidc.be/silso/datafiles
# Data Credits: The Sunspot Number data can be freely downloaded. However, we request that proper credit to the WDC-SILSO is explicitely included in any publication using our data (paper article or book, on-line Web content, etc.),
# Dat-Name: SN_d_tot_V2.0.csv

# %% [markdown]
# <h2>Aufgabe: Lesen Sie die Daten mit read_csv() in die Variable sunsets als Dataframe ein<br>
# und betrachten Sie den Dataframe mit .info()</h2>

# %% [markdown]
# <h3>Laden Sie die pandas Bibliothek (Welchen alias verwenden Sie ?)</h3>

# %% [markdown]
# <h3>Lösung:</h3>

# %%
import pandas as pd
dateipfad = 'SN_d_tot_V2.0.csv'
sunsets = pd.read_csv(dateipfad, sep=';', header=None)
sunsets.info()
sunsets.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73049 entries, 0 to 73048
# Data columns (total 8 columns):
# 0    73049 non-null int64
# 1    73049 non-null int64
# 2    73049 non-null int64
# 3    73049 non-null float64
# 4    73049 non-null int64
# 5    73049 non-null float64
# 6    73049 non-null int64
# 7    73049 non-null int64
# dtypes: float64(2), int64(6)
# memory usage: 4.5 MB
#       0  1   2         3   4     5  6  7
# 0  1818  1   1  1818.001  -1  -1.0  0  1
# 1  1818  1   2  1818.004  -1  -1.0  0  1
# 2  1818  1   3  1818.007  -1  -1.0  0  1
# 3  1818  1   4  1818.010  -1  -1.0  0  1
# 4  1818  1   5  1818.012  -1  -1.0  0  1
# 5  1818  1   6  1818.015  -1  -1.0  0  1
# 6  1818  1   7  1818.018  -1  -1.0  0  1
# 7  1818  1   8  1818.021  65  10.2  1  1
# 8  1818  1   9  1818.023  -1  -1.0  0  1
# 9  1818  1  10  1818.026  -1  -1.0  0  1

# %% [markdown]
# Dataframes kann man als csv und excel file im aktuellen Directory speichern mit:
# out_csv = 'example.csv'
# df.to_csv('out_csv', sep=(';'))
# out_xlsx = 'example.xlsx')
# df.to_excel('out_xlsx')

# %% [markdown]
# <h3>Geben Sie die Datenreihen 10:200 aus</h3>

# %%
sunsets.iloc[10:200, :]
# Out:
#         0  1   2         3    4     5  6  7
# 10   1818  1  11  1818.029   -1  -1.0  0  1
# 11   1818  1  12  1818.032   -1  -1.0  0  1
# 12   1818  1  13  1818.034   37   7.7  1  1
# 13   1818  1  14  1818.037   -1  -1.0  0  1
# 14   1818  1  15  1818.040   -1  -1.0  0  1
# 15   1818  1  16  1818.042   -1  -1.0  0  1
# 16   1818  1  17  1818.045   77  11.1  1  1
# 17   1818  1  18  1818.048   98  12.6  1  1
# 18   1818  1  19  1818.051  105  13.0  1  1
# 19   1818  1  20  1818.053   -1  -1.0  0  1
# 20   1818  1  21  1818.056   -1  -1.0  0  1
# 21   1818  1  22  1818.059   -1  -1.0  0  1
# 22   1818  1  23  1818.062   -1  -1.0  0  1
# 23   1818  1  24  1818.064   -1  -1.0  0  1
# 24   1818  1  25  1818.067   25   6.3  1  1
# 25   1818  1  26  1818.070   -1  -1.0  0  1
# 26   1818  1  27  1818.073   -1  -1.0  0  1
# 27   1818  1  28  1818.075   38   7.8  1  1
# 28   1818  1  29  1818.078   20   5.7  1  1
# 29   1818  1  30  1818.081   -1  -1.0  0  1
# 30   1818  1  31  1818.084   -1  -1.0  0  1
# 31   1818  2   1  1818.086   -1  -1.0  0  1
# 32   1818  2   2  1818.089   -1  -1.0  0  1
# 33   1818  2   3  1818.092   17   5.2  1  1
# 34   1818  2   4  1818.095   -1  -1.0  0  1
# 35   1818  2   5  1818.097   20   5.7  1  1
# 36   1818  2   6  1818.100   25   6.3  1  1
# 37   1818  2   7  1818.103   -1  -1.0  0  1
# 38   1818  2   8  1818.105   -1  -1.0  0  1
# 39   1818  2   9  1818.108   87  11.8  1  1
# ..    ... ..  ..       ...  ...   ... .. ..
# 170  1818  6  20  1818.467   67  10.3  1  1
# 171  1818  6  21  1818.470   90  12.0  1  1
# 172  1818  6  22  1818.473   83  11.6  1  1
# 173  1818  6  23  1818.475   70  10.6  1  1
# 174  1818  6  24  1818.478   52   9.1  1  1
# 175  1818  6  25  1818.481   -1  -1.0  0  1
# 176  1818  6  26  1818.484   65  10.2  1  1
# 177  1818  6  27  1818.486   73  10.8  1  1
# 178  1818  6  28  1818.489   75  11.0  1  1
# 179  1818  6  29  1818.492   97  12.5  1  1
# 180  1818  6  30  1818.495   88  11.9  1  1
# 181  1818  7   1  1818.497   57   9.5  1  1
# 182  1818  7   2  1818.500   18   5.4  1  1
# 183  1818  7   3  1818.503   22   5.9  1  1
# 184  1818  7   4  1818.505   57   9.5  1  1
# 185  1818  7   5  1818.508   72  10.7  1  1
# 186  1818  7   6  1818.511   -1  -1.0  0  1
# 187  1818  7   7  1818.514   35   7.5  1  1
# 188  1818  7   8  1818.516   25   6.3  1  1
# 189  1818  7   9  1818.519   20   5.7  1  1
# 190  1818  7  10  1818.522   33   7.3  1  1
# 191  1818  7  11  1818.525   45   8.5  1  1
# 192  1818  7  12  1818.527   -1  -1.0  0  1
# 193  1818  7  13  1818.530   -1  -1.0  0  1
# 194  1818  7  14  1818.533   58   9.7  1  1
# 195  1818  7  15  1818.536   53   9.3  1  1
# 196  1818  7  16  1818.538   -1  -1.0  0  1
# 197  1818  7  17  1818.541   37   7.7  1  1
# 198  1818  7  18  1818.544   42   8.2  1  1
# 199  1818  7  19  1818.547   -1  -1.0  0  1
#
# [190 rows x 8 columns]

# %% [markdown]
# Wir können jetzt einige Probleme erkennen. Die Spaltenüberschriften machten einfach keinen Sinn.<br>
# Man mussten mit header=None arbeiten.Und hier gibt es überraschend in Spalte 5 EInträge der Art<br>
# -1.0.
# Die -1.0 Einträge bedeuten, das kein Wert vorhanden ist.
# Die Datei enthält folgende Werte:<br>
# Column 1-3: Gregorian calendar date
# - Year
# - Month
# - Day
# Column 4: Date in fraction of year
# Column 5: Daily total sunspot number. A value of -1 indicates that no number is available for that day (missing value).
# Column 6: Daily standard deviation of the input sunspot numbers from individual stations.
# Column 7: Number of observations used to compute the daily value.
# Column 8: Definitive/provisional indicator. A blank indicates that the value is definitive. A '*' symbol indicates that the value is still provisional and is subject to a possible revision (Usually the last 3 to 6 months)

# %% [markdown]
# Wir wollen in der datei die Dpaltennamen ändern

# %%
spalten_namen=['Jahr','Monat','Dez_Tag', 'Sunspot', 'Stabw','Definitv','Observationen']

# %%
sun_spots=pd.read_csv(dateipfad, header=None, sep =';', names=spalten_namen)

# %%
sun_spots.head(10)
sun_spots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73049 entries, 1818 to 2017
# Data columns (total 7 columns):
# Jahr             73049 non-null int64
# Monat            73049 non-null int64
# Dez_Tag          73049 non-null float64
# Sunspot          73049 non-null int64
# Stabw            73049 non-null float64
# Definitv         73049 non-null int64
# Observationen    73049 non-null int64
# dtypes: float64(2), int64(5)
# memory usage: 4.5 MB

# %% [markdown]
# Wenn wir wissen dass die -1 Werte nicht vorhandene Werte repräsentiert,
# dann können wir das bereits beim Einlesen der Daten berücksichtigen.

# %%
sunny_spots=pd.read_csv(dateipfad, header=None, sep =';', names=spalten_namen, na_values=' -1')

# %%
sunny_spots.head(10)
sunny_spots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73049 entries, 1818 to 2017
# Data columns (total 7 columns):
# Jahr             73049 non-null int64
# Monat            73049 non-null int64
# Dez_Tag          73049 non-null float64
# Sunspot          73049 non-null int64
# Stabw            69802 non-null float64
# Definitv         73049 non-null int64
# Observationen    73049 non-null int64
# dtypes: float64(2), int64(5)
# memory usage: 4.5 MB

# %%
sunny_spots.head(10)
# Out:
#       Jahr  Monat   Dez_Tag  Sunspot  Stabw  Definitv  Observationen
# 1818     1      1  1818.001       -1    NaN         0              1
# 1818     1      2  1818.004       -1    NaN         0              1
# 1818     1      3  1818.007       -1    NaN         0              1
# 1818     1      4  1818.010       -1    NaN         0              1
# 1818     1      5  1818.012       -1    NaN         0              1
# 1818     1      6  1818.015       -1    NaN         0              1
# 1818     1      7  1818.018       -1    NaN         0              1
# 1818     1      8  1818.021       65   10.2         1              1
# 1818     1      9  1818.023       -1    NaN         0              1
# 1818     1     10  1818.026       -1    NaN         0              1

# %% [markdown]
# <h2>Aus panda datframes direkt plotten</h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3>Einlesen historischer Aktienwerte von Apple. Quelle yahoo finance</h3>

# %%
aapl = pd.read_csv('AAPL.csv')

# %%
aapl.head(5)
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2014-01-21  77.284286  78.581429  77.202858  78.438568  72.721451
# 1  2014-01-22  78.701431  79.612854  78.258568  78.787140  73.044617
# 2  2014-01-23  78.562859  79.500000  77.830002  79.454285  73.663139
# 3  2014-01-24  79.142860  79.374283  77.821426  78.010002  72.324127
# 4  2014-01-27  78.581429  79.257141  77.964287  78.642860  72.910835
#
#       Volume
# 0   82131700
# 1   94996300
# 2  100809800
# 3  107338700
# 4  138719700

# %%
aapl = pd.read_csv('AAPL.csv',sep=',', index_col='Date')

# %%
aapl.head(5)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2014-01-21  77.284286  78.581429  77.202858  78.438568  72.721451   82131700
# 2014-01-22  78.701431  79.612854  78.258568  78.787140  73.044617   94996300
# 2014-01-23  78.562859  79.500000  77.830002  79.454285  73.663139  100809800
# 2014-01-24  79.142860  79.374283  77.821426  78.010002  72.324127  107338700
# 2014-01-27  78.581429  79.257141  77.964287  78.642860  72.910835  138719700

# %%
aapl = pd.read_csv('AAPL.csv', sep=',', index_col='Date', parse_dates=True)

# %%
aapl.head(5)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2014-01-21  77.284286  78.581429  77.202858  78.438568  72.721451   82131700
# 2014-01-22  78.701431  79.612854  78.258568  78.787140  73.044617   94996300
# 2014-01-23  78.562859  79.500000  77.830002  79.454285  73.663139  100809800
# 2014-01-24  79.142860  79.374283  77.821426  78.010002  72.324127  107338700
# 2014-01-27  78.581429  79.257141  77.964287  78.642860  72.910835  138719700

# %%
close_arr=aapl['Close'].values

# %%
print(close_arr)
# Out:
# [  78.438568   78.78714    79.454285 ...,  179.100006  179.259995
#   178.460007]

# %%
aapl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1008 entries, 2014-01-21 to 2018-01-19
# Data columns (total 6 columns):
# Open         1008 non-null float64
# High         1008 non-null float64
# Low          1008 non-null float64
# Close        1008 non-null float64
# Adj Close    1008 non-null float64
# Volume       1008 non-null int64
# dtypes: float64(5), int64(1)
# memory usage: 55.1 KB

# %%
type(close_arr)
# Out:
# numpy.ndarray

# %%
plt.plot(close_arr)
plt.show()

# %% [markdown]
# <h3>Einlesen historischer Aktienwerte von Amazon. Quelle yahoo finance</h3>

# %%
amzn = pd.read_csv('AMZN.csv', sep=',', index_col='Date', parse_dates=True)

# %%
close_arr=amzn['Close'].values

# %%
plt.plot(close_arr)
plt.show()

# %%
close_series = amzn['Close']

# %%
plt.plot(close_series)
plt.show()

# %%
#Serien direkt plotten
close_series.plot()
plt.show()

# %%
amzn.plot()
plt.show()

# %%
plt.plot(amzn)
plt.show()

# %%
amzn.plot()
#Logarithmische Skala auf der y-Achse
plt.yscale('log')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
amzn['Open'].plot(color='b',legend=True)
amzn['Close'].plot(color='r',legend=True)
#plt.axis('2014','2018',0,100)
plt.show()

# %%
amzn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1008 entries, 2014-01-21 to 2018-01-19
# Data columns (total 6 columns):
# Open         1008 non-null float64
# High         1008 non-null float64
# Low          1008 non-null float64
# Close        1008 non-null float64
# Adj Close    1008 non-null float64
# Volume       1008 non-null int64
# dtypes: float64(5), int64(1)
# memory usage: 55.1 KB

# %%
amzn.loc['2016':'2018',['Open']].plot()
plt.show()

# %%
amzn.loc['2015':'2018',['Close']].plot()
plt.savefig('amzn.png')
plt.savefig('amzn.jpg')
plt.savefig('amzn.pdf')
plt.show()

# %% [markdown]
# <h3>Einlesen einer csv Datei: temperaturen-1300.csv sep=; decimal = ,</h3>

# %%
temp=pd.read_csv('temperaturen-1300.csv',sep=(';'),decimal=(','))

# %%
temp.head()
# Out:
#    ﻿Temperatur
# 0       72.489
# 1       79.459
# 2       70.490
# 3       68.850
# 4       73.144

# %%
print(temp)
# Out:
#       ﻿Temperatur
# 0          72.489
# 1          79.459
# 2          70.490
# 3          68.850
# 4          73.144
# 5          78.818
# 6          75.312
# 7          78.170
# 8          75.569
# 9          78.797
# 10         71.011
# 11         77.718
# 12         74.112
# 13         67.589
# 14         74.961
# 15         71.566
# 16         67.401
# 17         71.552
# 18         79.251
# 19         69.891
# 20         78.486
# 21         67.700
# 22         74.385
# 23         77.157
# 24         75.793
# 25         72.328
# 26         71.801
# 27         78.359
# 28         67.639
# 29         76.298
# ...           ...
# 1268       67.796
# 1269       68.807
# 1270       75.093
# 1271       68.528
# 1272       77.649
# 1273       71.212
# 1274       77.381
# 1275       78.327
# 1276       73.563
# 1277       68.347
# 1278       71.325
# 1279       74.346
# 1280       71.952
# 1281       73.965
# 1282       72.535
# 1283       65.026
# 1284       76.320
# 1285       65.486
# 1286       68.968
# 1287       69.338
# 1288       77.521
# 1289       73.397
# 1290       74.567
# 1291       70.204
# 1292       70.140
# 1293       75.687
# 1294       67.489
# 1295       67.926
# 1296       66.928
# 1297       77.132
#
# [1298 rows x 1 columns]

# %%
plt.plot(temp)
plt.show()

# %%
# Create a plot with color='red'
temp.plot(color='r')

# Add a title
plt.title('Temperatur')

# Specify the x-axis label
plt.xlabel('Stunden seit Mitternacht 1. August 2015')

# Specify the y-axis label
plt.ylabel('Temperatur (Grad C)')

# Display the plot
plt.show()

# %% [markdown]
# <h3>Einlesen einer csv-Datei: wetterdaten-1300.csv header=0 sep=; decimal = ,</h3>

# %%
wett=pd.read_csv('wetterdaten-1300.csv',header=0, sep=(';'),decimal=(','))

# %%
wett.head()
# Out:
#    Temperatur  Luftdruck
# 0      69.017       9.750
# 1      79.459       9.702
# 2      70.490       9.711
# 3      68.850       9.725
# 4      73.144       9.751

# %%
wett.plot()
plt.show()

# %%
wett.plot(subplots=True)
plt.show()

# %%
# Plot all columns (default)
wett.plot()
plt.show()

# Plot all columns as subplots
wett.plot(subplots=True)
plt.show()
#
col_list1=['Temperatur']
wett[col_list1].plot()
plt.show()
col_list2=['Luftdruck ']
wett[col_list2].plot()
plt.show()

# %%
wett.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1298 entries, 0 to 1297
# Data columns (total 2 columns):
# Temperatur    1298 non-null float64
# Luftdruck     1298 non-null float64
# dtypes: float64(2)
# memory usage: 20.4 KB

# %%
wett.columns
# Out:
# Index([u'Temperatur', u'Luftdruck '], dtype='object')

# %% [markdown]
# <h3>Einlesen hstorischer Aktienwerte S&P500 Quelle yahoo finance</h3>

# %%
gspc = pd.read_csv('GSPC-2000-2018.csv', sep=',', index_col='Date', parse_dates=True)

# %%
close_series = gspc['Close']

# %%
#Serien direkt plotten
close_series.plot(title='S&P 500')
plt.ylabel('Closing in US$')
plt.show()

# %%
gspc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4542 entries, 1999-12-31 to 2018-01-19
# Data columns (total 6 columns):
# Open         4542 non-null float64
# High         4542 non-null float64
# Low          4542 non-null float64
# Close        4542 non-null float64
# Adj Close    4542 non-null float64
# Volume       4542 non-null int64
# dtypes: float64(5), int64(1)
# memory usage: 248.4 KB

# %%
gspc.columns
# Out:
# Index([u'Open', u'High', u'Low', u'Close', u'Adj Close', u'Volume'], dtype='object')

# %%
gspc['Close'].mean()
# Out:
# 1439.3966907626593

# %%
gspc['Close'].std()
# Out:
# 434.61170722993614

# %%
gspc.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1999-12-31  1464.469971  1472.420044  1458.189941  1469.250000  1469.250000
# 2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971  1455.219971
# 2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044  1399.420044
# 2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985  1402.109985
# 2000-01-06  1402.109985  1411.900024  1392.099976  1403.449951  1403.449951
#
#                 Volume
# Date
# 1999-12-31   374050000
# 2000-01-03   931800000
# 2000-01-04  1009000000
# 2000-01-05  1085500000
# 2000-01-06  1092300000

# %%
gspc.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-01-12  2770.179932  2787.850098  2769.639893  2786.239990  2786.239990
# 2018-01-16  2798.959961  2807.540039  2768.639893  2776.419922  2776.419922
# 2018-01-17  2784.989990  2807.040039  2778.379883  2802.560059  2802.560059
# 2018-01-18  2802.399902  2805.830078  2792.560059  2798.030029  2798.030029
# 2018-01-19  2802.600098  2810.330078  2798.080078  2810.300049  2810.300049
#
#                 Volume
# Date
# 2018-01-12  3573970000
# 2018-01-16  4325970000
# 2018-01-17  3778050000
# 2018-01-18  3681470000
# 2018-01-19  3609430000

# %%
gspc.loc['2015-01-01':'2016-01-01', 'Close'].plot(title='S&P 500')
plt.ylabel('Closing in US$')
plt.show()

# %%
gspc.loc['2015-01-01':'2015-02-01', 'Close'].plot(title='S&P 500', style='k.-')
plt.ylabel('Closing in US$')
plt.show()

# %%
gspc.loc['2015-01-01':'2015-02-01', 'Close'].plot(title='S&P 500', style='r.-')
plt.ylabel('Closing in US$')
plt.show()

# %%
gspc.loc['2015-01-01':'2015-02-01', 'Close'].plot(title='S&P 500', kind='box')
plt.ylabel('Closing in US$')
plt.show()

# %%
gspc.loc['2015-01-01':'2016-02-01', 'Close'].plot(title='S&P 500', kind='hist', bins=30)
plt.ylabel('Closing in US$')
plt.show()

# %%
gspc.loc['2015-01-01':'2016-02-01', 'Close'].plot(title='S&P 500', kind='box')
plt.ylabel('Closing in US$')
plt.savefig('gspc2015.png')
plt.show()
